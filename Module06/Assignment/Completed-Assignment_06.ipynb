# %% [markdown]
# # Assignment 6:  Due Thursday 10/10
#
# In this assignment you will become familiar with the Pandas library through the exploration of a Nobel prize data set.
#
# This data set was taken from the Kaggle website (https://www.kaggle.com/). If you are interested in data science and / or analysis, this website offers tons of data sets in various formats that you can access. They even post compititions that you can enter, some with money prizes awarded.
#
# The libraries needed for this assignment are listed below.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 1a)
#
# Read in the data set 'data/nobel.csv' into a DataFrame using Pandas .

# %%
inpath = %pwd
print(inpath)
infile = inpath +'/nobel.csv'

df = pd.read_csv(infile)
df
# Out:
# C:\Users\joe86\Downloads
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 1    "in special recognition of his poetic composit...         1/1
# 2    "for his work on serum therapy, especially its...         1/1
# 3                                                  NaN         1/2
# 4                                                  NaN         1/2
# ..                                                 ...         ...
# 906  "for his discoveries of mechanisms for autophagy"         1/1
# 907  "for his resolute efforts to bring the country...         1/1
# 908  "for theoretical discoveries of topological ph...         1/2
# 909  "for theoretical discoveries of topological ph...         1/4
# 910  "for theoretical discoveries of topological ph...         1/4
#
#      laureate_id laureate_type                     full_name  birth_date  \
# 0            160    Individual  Jacobus Henricus van 't Hoff  1852-08-30
# 1            569    Individual               Sully Prudhomme  1839-03-16
# 2            293    Individual        Emil Adolf von Behring  1854-03-15
# 3            462    Individual             Jean Henry Dunant  1828-05-08
# 4            463    Individual                Frédéric Passy  1822-05-20
# ..           ...           ...                           ...         ...
# 906          927    Individual              Yoshinori Ohsumi  1945-02-09
# 907          934    Individual            Juan Manuel Santos  1951-08-10
# 908          928    Individual             David J. Thouless  1934-09-21
# 909          929    Individual          F. Duncan M. Haldane  1951-09-14
# 910          930    Individual         J. Michael Kosterlitz  1943-06-22
#
#             birth_city     birth_country   sex              organization_name  \
# 0            Rotterdam       Netherlands  Male              Berlin University
# 1                Paris            France  Male                            NaN
# 2    Hansdorf (Lawice)  Prussia (Poland)  Male             Marburg University
# 3               Geneva       Switzerland  Male                            NaN
# 4                Paris            France  Male                            NaN
# ..                 ...               ...   ...                            ...
# 906            Fukuoka             Japan  Male  Tokyo Institute of Technology
# 907             Bogotá          Colombia  Male                            NaN
# 908           Bearsden    United Kingdom  Male       University of Washington
# 909             London    United Kingdom  Male           Princeton University
# 910           Aberdeen    United Kingdom  Male               Brown University
#
#     organization_city      organization_country  death_date death_city  \
# 0              Berlin                   Germany  1911-03-01     Berlin
# 1                 NaN                       NaN  1907-09-07   Châtenay
# 2             Marburg                   Germany  1917-03-31    Marburg
# 3                 NaN                       NaN  1910-10-30     Heiden
# 4                 NaN                       NaN  1912-06-12      Paris
# ..                ...                       ...         ...        ...
# 906             Tokyo                     Japan         NaN        NaN
# 907               NaN                       NaN         NaN        NaN
# 908       Seattle, WA  United States of America         NaN        NaN
# 909     Princeton, NJ  United States of America         NaN        NaN
# 910    Providence, RI  United States of America         NaN        NaN
#
#     death_country
# 0         Germany
# 1          France
# 2         Germany
# 3     Switzerland
# 4          France
# ..            ...
# 906           NaN
# 907           NaN
# 908           NaN
# 909           NaN
# 910           NaN
#
# [911 rows x 18 columns]

# %% [markdown]
# # 1b)
#
# Display below the output from the DataFrame functions *info*.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  911 non-null    int64
#  1   category              911 non-null    object
#  2   prize                 911 non-null    object
#  3   motivation            823 non-null    object
#  4   prize_share           911 non-null    object
#  5   laureate_id           911 non-null    int64
#  6   laureate_type         911 non-null    object
#  7   full_name             911 non-null    object
#  8   birth_date            883 non-null    object
#  9   birth_city            883 non-null    object
#  10  birth_country         885 non-null    object
#  11  sex                   885 non-null    object
#  12  organization_name     665 non-null    object
#  13  organization_city     667 non-null    object
#  14  organization_country  667 non-null    object
#  15  death_date            593 non-null    object
#  16  death_city            576 non-null    object
#  17  death_country         582 non-null    object
# dtypes: int64(2), object(16)
# memory usage: 128.2+ KB

# %% [markdown]
# # 1c)
#
# Show the first 5 listings of the dataset.

# %%
df.head(5)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff  1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme  1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring  1854-03-15  Hansdorf (Lawice)
# 3    Individual             Jean Henry Dunant  1828-05-08             Geneva
# 4    Individual                Frédéric Passy  1822-05-20              Paris
#
#       birth_country   sex   organization_name organization_city  \
# 0       Netherlands  Male   Berlin University            Berlin
# 1            France  Male                 NaN               NaN
# 2  Prussia (Poland)  Male  Marburg University           Marburg
# 3       Switzerland  Male                 NaN               NaN
# 4            France  Male                 NaN               NaN
#
#   organization_country  death_date death_city death_country
# 0              Germany  1911-03-01     Berlin       Germany
# 1                  NaN  1907-09-07   Châtenay        France
# 2              Germany  1917-03-31    Marburg       Germany
# 3                  NaN  1910-10-30     Heiden   Switzerland
# 4                  NaN  1912-06-12      Paris        France

# %% [markdown]
# # Problem 2
#
# How many null ('NaN') values there are in each *catagory*? What is the total number of Null values in the DataFrame?

# %%
df.isnull().sum()
# Out:
# year                      0
# category                  0
# prize                     0
# motivation               88
# prize_share               0
# laureate_id               0
# laureate_type             0
# full_name                 0
# birth_date               28
# birth_city               28
# birth_country            26
# sex                      26
# organization_name       246
# organization_city       244
# organization_country    244
# death_date              318
# death_city              335
# death_country           329
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 1912

# %% [markdown]
# # Problem 3
#
# Make a histogram of the number of nobel prizes awarded per year. Around which decade (1900, 1910, 1920, ...) were the least amount of prizes awarded?

# %%
prizes_per_year = df['year'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
plt.hist(prizes_per_year.index, bins=range(prizes_per_year.index.min(), prizes_per_year.index.max() + 1, 1), weights=prizes_per_year, edgecolor='black')
plt.title('Number of Nobel Prizes Awarded per Year')
plt.xlabel('Year')
plt.ylabel('Number of Prizes')

df['decade'] = (df['year'] // 10) * 10
prizes_per_decade = df['decade'].value_counts().sort_index()

least_prizes_decade = prizes_per_decade.idxmin()
print(f"The decade with the least prizes awarded: {least_prizes_decade}")
# Out:
# The decade with the least prizes awarded: 1910

# %% [markdown]
# # Problem 4
#
# Use groupby method to printout the number of prizes awarded to each category. Which categroy has the most prizes?

# %%
category_counts = df.groupby('category').size()

print(category_counts)

most_prizes_category = category_counts.idxmax()
print(f"The category with the most prizes awarded: {most_prizes_category}")
# Out:
# category
# Chemistry     175
# Economics      78
# Literature    113
# Medicine      211
# Peace         130
# Physics       204
# dtype: int64
# The category with the most prizes awarded: Medicine

# %% [markdown]
# # Problem 5
#
# Find percentage of the prizes were awarded to 1, 2, 3, and 4 people? Meaning what percentage of 1/1, 1/2, 1/3, and 1/4 prize_shares are there?

# %%
total_prizes = len(df)

prize_share_counts = df['prize_share'].value_counts()

prize_share_percentages = (prize_share_counts / total_prizes) * 100

print(prize_share_counts)

shares_of_interest = ['1/1', '1/2', '1/3', '1/4']

for share in shares_of_interest:
    
        print(f"Percentage of prizes awarded to {share}: {prize_share_percentages[share]:.2f}%")
# Out:
# prize_share
# 1/1    344
# 1/2    306
# 1/3    201
# 1/4     60
# Name: count, dtype: int64
# Percentage of prizes awarded to 1/1: 37.76%
# Percentage of prizes awarded to 1/2: 33.59%
# Percentage of prizes awarded to 1/3: 22.06%
# Percentage of prizes awarded to 1/4: 6.59%

# %% [markdown]
# # Problem 6
#
# Determine how many males and females won the prize. Does the sum of male and female prizes add up to the total entries? If not, why?
#
# On the same graph make histograms for the numbber of males and females that won the prize each year.

# %%
sex_counts = df['sex'].value_counts()

print(sex_counts)

total_entries = len(df)
print(f"Total entries: {total_entries}")
print(f"Sum of male and female prizes: {sex_counts.sum()}")
print(f"Do they add up? {'Yes' if sex_counts.sum() == total_entries else 'No'}")

winners_per_year = df.groupby(['year', 'sex']).size().unstack(fill_value=0)

plt.figure(figsize=(100, 6))
winners_per_year.plot(kind='bar', stacked=True)
plt.title('Number of Male and Female Nobel Prize Winners per Year')
plt.xlabel('Year')
plt.ylabel('Number of Winners')
plt.legend(title='sex')
# Out:
# sex
# Male      836
# Female     49
# Name: count, dtype: int64
# Total entries: 911
# Sum of male and female prizes: 885
# Do they add up? No

# %% [markdown]
# # Problem 7
#
# How many prizes were won by those whose birth country was United States of America?

# %%
usa_prizes = df[df['birth_country'] == 'United States of America']

number_of_usa_prizes = len(usa_prizes)

print(f"Number of Nobel Prizes won by individuals born in the United States of America: {number_of_usa_prizes}")
# Out:
# Number of Nobel Prizes won by individuals born in the United States of America: 259

# %% [markdown]
# # Problem 8
#
# Determine the age that each of the prize winners was when they won the prize. Find the youngest and oldest to win the prize. Find the mean age to win the prize, and the standard deviation of it. Make a histogram of the age each person was when they won the prize.
#
# ### Hint: You can use Pandas DatetimeIndex method to extract the year from the date format yyyy-mm-dd
# > pd.DatetimeIndex(date).year
#
# Where *date* is given in a formate like year-month-day, the above will returen the year, hence the *.year* in the call above. Use 'shit+tab' on pandas.DatetimeIndex to learn more.

# %%
df['birth_year'] = pd.DatetimeIndex(df['birth_date']).year

# Step 2: Calculate the age at which the prize was won
df['age_at_award'] = df['year'] - df['birth_year']

# Step 3: Find the youngest and oldest winners
youngest_winner = df['age_at_award'].min()
oldest_winner = df['age_at_award'].max()

# Step 4: Calculate mean age and standard deviation
mean_age = df['age_at_award'].mean()
std_dev_age = df['age_at_award'].std()

# Print results
print(f"Youngest winner age: {youngest_winner}")
print(f"Oldest winner age: {oldest_winner}")
print(f"Mean age at award: {mean_age:.2f}")
print(f"Standard deviation of age at award: {std_dev_age:.2f}")

# Step 5: Create a histogram of ages at award
plt.figure(figsize=(12, 6))
plt.hist(df['age_at_award'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Ages at Nobel Prize Award')
plt.xlabel('Age at Award')
plt.ylabel('Number of Winners')
# Out:
# Youngest winner age: 17.0
# Oldest winner age: 90.0
# Mean age at award: 59.45
# Standard deviation of age at award: 12.40
# Text(0, 0.5, 'Number of Winners')

# %% [markdown]
# # Problem 9
#
# Make a copy of the current DataFrame. Then drop the column *lauret_id* from the copied DataFrame (do this inplace so this column is gone).

# %%
df_copy = df.copy()

df_copy.drop(columns=['laureate_id'], inplace=True)

df_copy.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  \
# 0  "in recognition of the extraordinary services ...         1/1
# 1  "in special recognition of his poetic composit...         1/1
# 2  "for his work on serum therapy, especially its...         1/1
# 3                                                NaN         1/2
# 4                                                NaN         1/2
#
#   laureate_type                     full_name  birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff  1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme  1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring  1854-03-15  Hansdorf (Lawice)
# 3    Individual             Jean Henry Dunant  1828-05-08             Geneva
# 4    Individual                Frédéric Passy  1822-05-20              Paris
#
#       birth_country   sex   organization_name organization_city  \
# 0       Netherlands  Male   Berlin University            Berlin
# 1            France  Male                 NaN               NaN
# 2  Prussia (Poland)  Male  Marburg University           Marburg
# 3       Switzerland  Male                 NaN               NaN
# 4            France  Male                 NaN               NaN
#
#   organization_country  death_date death_city death_country  decade  \
# 0              Germany  1911-03-01     Berlin       Germany    1900
# 1                  NaN  1907-09-07   Châtenay        France    1900
# 2              Germany  1917-03-31    Marburg       Germany    1900
# 3                  NaN  1910-10-30     Heiden   Switzerland    1900
# 4                  NaN  1912-06-12      Paris        France    1900
#
#    birth_year  age_at_award
# 0      1852.0          49.0
# 1      1839.0          62.0
# 2      1854.0          47.0
# 3      1828.0          73.0
# 4      1822.0          79.0

# %% [markdown]
# # Problem 10
#
# Add the age column you calculated in Problem 8 to the DataFrame.

# %%
#made a column called 'age_at_award' for problem 8. Removing it and adding it back wit hthe name 'age'
df.drop(columns=['age_at_award'], inplace=True)

df['birth_year'] = pd.DatetimeIndex(df['birth_date']).year

df['age'] = df['year'] - df['birth_year']

df.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# 0    Individual  Jacobus Henricus van 't Hoff  1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme  1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring  1854-03-15  Hansdorf (Lawice)
# 3    Individual             Jean Henry Dunant  1828-05-08             Geneva
# 4    Individual                Frédéric Passy  1822-05-20              Paris
#
#    ...   sex   organization_name organization_city organization_country  \
# 0  ...  Male   Berlin University            Berlin              Germany
# 1  ...  Male                 NaN               NaN                  NaN
# 2  ...  Male  Marburg University           Marburg              Germany
# 3  ...  Male                 NaN               NaN                  NaN
# 4  ...  Male                 NaN               NaN                  NaN
#
#    death_date death_city death_country decade  birth_year   age
# 0  1911-03-01     Berlin       Germany   1900      1852.0  49.0
# 1  1907-09-07   Châtenay        France   1900      1839.0  62.0
# 2  1917-03-31    Marburg       Germany   1900      1854.0  47.0
# 3  1910-10-30     Heiden   Switzerland   1900      1828.0  73.0
# 4  1912-06-12      Paris        France   1900      1822.0  79.0
#
# [5 rows x 21 columns]
